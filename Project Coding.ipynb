# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings( "ignore")

# %%
mydata=pd.read_csv('Social+Media+Data+for+DSBA.csv')

# %%
mydata.head()
# Out:
#     UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 0  1000001           Yes                           307.0  iOS and Android
# 1  1000002            No                           367.0              iOS
# 2  1000003           Yes                           277.0  iOS and Android
# 3  1000004            No                           247.0              iOS
# 4  1000005            No                           202.0  iOS and Android
#
#    total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 0                                  38570.0                              1
# 1                                   9765.0                              1
# 2                                  48055.0                              1
# 3                                  48720.0                              1
# 4                                  20685.0                              1
#
# ...

# %%
mydata.tail()
# Out:
#         UserID Taken_product  Yearly_avg_view_on_travel_page preferred_device  \
# 11755  1011756            No                           279.0           Laptop
# 11756  1011757            No                           305.0              Tab
# 11757  1011758            No                           214.0              Tab
# 11758  1011759            No                           382.0           Laptop
# 11759  1011760            No                           270.0              Tab
#
#        total_likes_on_outstation_checkin_given yearly_avg_Outstation_checkins  \
# 11755                                  30987.0                             23
# 11756                                  21510.0                              6
# 11757                                   5478.0                              4
# 11758                                  35851.0                              2
# 11759                                  22025.0                              8
#
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   UserID                                        11760 non-null  int64
#  1   Taken_product                                 11760 non-null  object
#  2   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  3   preferred_device                              11707 non-null  object
#  4   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  5   yearly_avg_Outstation_checkins                11685 non-null  object
#  6   member_in_family                              11760 non-null  object
#  7   preferred_location_type                       11729 non-null  object
#  8   Yearly_avg_comment_on_travel_page             11554 non-null  float64
# ...

# %%
mydata.dtypes.value_counts()
# Out:
# int64      7
# object     7
# float64    3
# dtype: int64

# %%
print("no. of rows: ",mydata.shape[0], "\n""no. of columns: ",mydata.shape[1])
# Out:
# no. of rows:  11760
# no. of columns:  17

# %%
mydata.describe().T
# Out:
#                                                 count          mean  \
# UserID                                        11760.0  1.005880e+06
# Yearly_avg_view_on_travel_page                11179.0  2.808308e+02
# total_likes_on_outstation_checkin_given       11379.0  2.817048e+04
# Yearly_avg_comment_on_travel_page             11554.0  7.479003e+01
# total_likes_on_outofstation_checkin_received  11760.0  6.531699e+03
# week_since_last_outstation_checkin            11760.0  3.203571e+00
# montly_avg_comment_on_company_page            11760.0  2.866156e+01
# travelling_network_rating                     11760.0  2.712245e+00
# Adult_flag                                    11760.0  7.938776e-01
# Daily_Avg_mins_spend_on_traveling_page        11760.0  1.381743e+01
#
#                                                        std        min  \
# UserID                                         3394.963917  1000001.0
# Yearly_avg_view_on_travel_page                   68.182958       35.0
# ...

# %%
mydata.isnull().sum()
# Out:
# UserID                                            0
# Taken_product                                     0
# Yearly_avg_view_on_travel_page                  581
# preferred_device                                 53
# total_likes_on_outstation_checkin_given         381
# yearly_avg_Outstation_checkins                   75
# member_in_family                                  0
# preferred_location_type                          31
# Yearly_avg_comment_on_travel_page               206
# total_likes_on_outofstation_checkin_received      0
# week_since_last_outstation_checkin                0
# following_company_page                          103
# montly_avg_comment_on_company_page                0
# working_flag                                      0
# travelling_network_rating                         0
# Adult_flag                                        0
# Daily_Avg_mins_spend_on_traveling_page            0
# dtype: int64

# %%
mydata.isnull().sum().sum()
# Out:
# 1430

# %%
mydata.duplicated().sum()
# Out:
# 0

# %%
#Treating all bad data

# %%
mydata.preferred_location_type.value_counts(dropna=False)
# Out:
# Beach              2424
# Financial          2409
# Historical site    1856
# Medical            1845
# Other               643
# Big Cities          636
# Social media        633
# Trekking            528
# Entertainment       516
# Hill Stations       108
# Tour  Travel         60
# Tour and Travel      47
# NaN                  31
# Game                 12
# OTT                   7
# Movie                 5
# Name: preferred_location_type, dtype: int64

# %%
mydata['preferred_location_type'] = np.where(mydata['preferred_location_type']=='Tour  Travel','Tour and Travel',mydata['preferred_location_type'])

# %%
mydata.preferred_location_type.value_counts(dropna=False)
# Out:
# Beach              2424
# Financial          2409
# Historical site    1856
# Medical            1845
# Other               643
# Big Cities          636
# Social media        633
# Trekking            528
# Entertainment       516
# Hill Stations       108
# Tour and Travel     107
# NaN                  31
# Game                 12
# OTT                   7
# Movie                 5
# Name: preferred_location_type, dtype: int64

# %%
mydata.yearly_avg_Outstation_checkins.value_counts(dropna=False)
# Out:
# 1      4543
# 2       844
# 10      682
# 9       340
# 7       336
# 3       336
# 8       320
# 5       261
# 4       256
# 16      255
# 6       236
# 11      229
# 24      223
# 29      215
# 23      215
# 18      208
# 15      206
# 20      199
# 26      199
# 25      198
# 28      180
# 19      176
# 14      167
# 17      160
# 12      159
# 22      152
# 13      150
# 21      143
# 27       96
# NaN      75
# *         1
# Name: yearly_avg_Outstation_checkins, dtype: int64

# %%
# we have "*"" in data, we have to either convert this into missing values or 
# we can replace this with mode.

mydata.yearly_avg_Outstation_checkins = mydata.yearly_avg_Outstation_checkins.replace({"*":1,"1":1})
mydata.yearly_avg_Outstation_checkins.value_counts(dropna=False)
# Out:
# 1      4544
# 2       844
# 10      682
# 9       340
# 7       336
# 3       336
# 8       320
# 5       261
# 4       256
# 16      255
# 6       236
# 11      229
# 24      223
# 29      215
# 23      215
# 18      208
# 15      206
# 26      199
# 20      199
# 25      198
# 28      180
# 19      176
# 14      167
# 17      160
# 12      159
# 22      152
# 13      150
# 21      143
# 27       96
# NaN      75
# Name: yearly_avg_Outstation_checkins, dtype: int64

# %%
mydata.member_in_family.value_counts(dropna=False)
# Out:
# 3        4561
# 4        3184
# 2        2256
# 1        1349
# 5         384
# Three      15
# 10         11
# Name: member_in_family, dtype: int64

# %%
#Converting 'Three' into '3'

mydata.member_in_family = mydata.member_in_family.replace({"Three":3,"3":3})
mydata.member_in_family.value_counts(dropna=False)
# Out:
# 3     4576
# 4     3184
# 2     2256
# 1     1349
# 5      384
# 10      11
# Name: member_in_family, dtype: int64

# %%
mydata.working_flag.value_counts(dropna=False)
# Out:
# No     9952
# Yes    1808
# Name: working_flag, dtype: int64

# %%
mydata.Adult_flag.value_counts(dropna=False)
# Out:
# 0    5048
# 1    4768
# 2    1264
# 3     680
# Name: Adult_flag, dtype: int64

# %%
# here as per features there should be two factors be there as yes or no However we have 2 and 3 additional one 
# either we can assume 2 and 3 are adult
# we will assume first part as 2 and 3 are part of adult rest are minors
mydata.Adult_flag = np.where(mydata.Adult_flag >=1,1,0)
mydata.Adult_flag.value_counts(dropna=False)
# Out:
# 1    6712
# 0    5048
# Name: Adult_flag, dtype: int64

# %%
mydata.following_company_page.value_counts(dropna=False)
# Out:
# No     8355
# Yes    3285
# NaN     103
# 1        12
# 0         5
# Name: following_company_page, dtype: int64

# %%
mydata.following_company_page = mydata.following_company_page.str.replace('1','Yes').str.replace('0','No')
mydata.following_company_page.value_counts(dropna=False)
# Out:
# No     8360
# Yes    3297
# NaN     103
# Name: following_company_page, dtype: int64

# %%
mydata.preferred_device.value_counts(dropna=False)
# Out:
# Tab                4172
# iOS and Android    4134
# Laptop             1108
# iOS                1095
# Mobile              600
# Android             315
# Android OS          145
# ANDROID             134
# NaN                  53
# Other                 2
# Others                2
# Name: preferred_device, dtype: int64

# %%
mydata['preferred_device'] = np.where(mydata['preferred_device'] == 'Laptop','Laptop','Mobile')

# %%
mydata['preferred_device']=np.where(mydata['preferred_device'] =='Mobile','1', mydata['preferred_device'])
mydata['preferred_device']=np.where(mydata['preferred_device'] =='Laptop','0', mydata['preferred_device'])

# %%
mydata['preferred_device']=mydata['preferred_device'].astype('float64')
mydata.preferred_device.value_counts(dropna=False)
# Out:
# 1.0    10652
# 0.0     1108
# Name: preferred_device, dtype: int64

# %%
#dropping user id
mydata= mydata.drop(['UserID'], axis = 1)

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 11760 non-null  object
#  1   Yearly_avg_view_on_travel_page                11179 non-null  float64
#  2   preferred_device                              11760 non-null  float64
#  3   total_likes_on_outstation_checkin_given       11379 non-null  float64
#  4   yearly_avg_Outstation_checkins                11685 non-null  object
#  5   member_in_family                              11760 non-null  object
#  6   preferred_location_type                       11729 non-null  object
#  7   Yearly_avg_comment_on_travel_page             11554 non-null  float64
#  8   total_likes_on_outofstation_checkin_received  11760 non-null  int64
# ...

# %%
mydata.Taken_product.value_counts(dropna=False)
# Out:
# No     9864
# Yes    1896
# Name: Taken_product, dtype: int64

# %%
 #first what peercentage of missing valeus of data is missing

mydata.isnull().mean()*100
# Out:
# Taken_product                                   0.000000
# Yearly_avg_view_on_travel_page                  4.940476
# preferred_device                                0.000000
# total_likes_on_outstation_checkin_given         3.239796
# yearly_avg_Outstation_checkins                  0.637755
# member_in_family                                0.000000
# preferred_location_type                         0.263605
# Yearly_avg_comment_on_travel_page               1.751701
# total_likes_on_outofstation_checkin_received    0.000000
# week_since_last_outstation_checkin              0.000000
# following_company_page                          0.875850
# montly_avg_comment_on_company_page              0.000000
# working_flag                                    0.000000
# travelling_network_rating                       0.000000
# Adult_flag                                      0.000000
# Daily_Avg_mins_spend_on_traveling_page          0.000000
# dtype: float64

# %%
#As max missing values is less than 5% we can impute them. we will not drop any missing value

mydata[mydata.isnull().sum()[mydata.isnull().sum()>0].index].dtypes
# Out:
# Yearly_avg_view_on_travel_page             float64
# total_likes_on_outstation_checkin_given    float64
# yearly_avg_Outstation_checkins              object
# preferred_location_type                     object
# Yearly_avg_comment_on_travel_page          float64
# following_company_page                      object
# dtype: object

# %%
# we have float and object is missig values we impute float with median and object with mode

# Replacing NULL values in Numerical Columns using Median

median1=mydata["Yearly_avg_view_on_travel_page"].median()
median2=mydata["total_likes_on_outstation_checkin_given"].median()
median3=mydata["Yearly_avg_comment_on_travel_page"].median()

# %%
mydata["Yearly_avg_view_on_travel_page"].replace(np.nan,median1,inplace=True)
mydata["total_likes_on_outstation_checkin_given"].replace(np.nan,median2,inplace=True)
mydata["Yearly_avg_comment_on_travel_page"].replace(np.nan,median3,inplace=True)

# %%
mydata[mydata.isnull().sum()[mydata.isnull().sum()>0].index].dtypes
# Out:
# yearly_avg_Outstation_checkins    object
# preferred_location_type           object
# following_company_page            object
# dtype: object

# %%
# Replacing NULL values in object Columns using Mode

mode1=mydata["preferred_location_type"].mode().values[0]
mode2=mydata["following_company_page"].mode().values[0]
mode3=mydata["yearly_avg_Outstation_checkins"].mode().values[0]

# %%
mydata["preferred_location_type"]=mydata["preferred_location_type"].replace(np.nan,mode1)
mydata["following_company_page"]=mydata["following_company_page"].replace(np.nan,mode2)
mydata["yearly_avg_Outstation_checkins"]=mydata["yearly_avg_Outstation_checkins"].replace(np.nan,mode3)

# %%
mydata.isnull().sum()
# Out:
# Taken_product                                   0
# Yearly_avg_view_on_travel_page                  0
# preferred_device                                0
# total_likes_on_outstation_checkin_given         0
# yearly_avg_Outstation_checkins                  0
# member_in_family                                0
# preferred_location_type                         0
# Yearly_avg_comment_on_travel_page               0
# total_likes_on_outofstation_checkin_received    0
# week_since_last_outstation_checkin              0
# following_company_page                          0
# montly_avg_comment_on_company_page              0
# working_flag                                    0
# travelling_network_rating                       0
# Adult_flag                                      0
# Daily_Avg_mins_spend_on_traveling_page          0
# dtype: int64

# %%
mydata1 = mydata.select_dtypes(['int32','int64','float64']) 
a = len(mydata1.columns) # number of rows 
b = 2 # number of columns 
c = 1 # initialize plot counter 

fig = plt.figure(figsize=(15,40)) 
for i in mydata1.columns: 
    plt.subplot(a, b, c) 
    plt.xlabel(i) 
    sns.distplot(mydata1[i], hist_kws= dict(ec = 'black')) 
    c = c + 1 
    
    plt.subplot(a, b, c) 
    plt.xlabel(i) 
    sns.boxplot(x = mydata1[i]) 
    c = c + 1

# %%
mydata.skew()
# Out:
# Yearly_avg_view_on_travel_page                  0.446136
# preferred_device                               -2.778436
# total_likes_on_outstation_checkin_given         0.498413
# yearly_avg_Outstation_checkins                  0.977245
# member_in_family                                0.001205
# Yearly_avg_comment_on_travel_page               4.910947
# total_likes_on_outofstation_checkin_received    1.368578
# week_since_last_outstation_checkin              0.915334
# montly_avg_comment_on_company_page              7.684150
# travelling_network_rating                      -0.302557
# Adult_flag                                     -0.285906
# Daily_Avg_mins_spend_on_traveling_page          4.480682
# dtype: float64

# %%
mydata2 = mydata.select_dtypes(['object','category']) 
a = len(mydata2.columns) # number of rows 
b = 2 # number of columns 
c = 1 # initialize plot counter 
fig = plt.figure(figsize=(15,60))  

for i in mydata2.columns: 
    plt.subplot(a, b, c) 
    plt.xlabel(i,fontsize =10) 
    plt.xticks(rotation=90) 
    ax1 = sns.countplot(mydata2[i]) 
    c = c + 1

# %%
 sns.countplot(x='preferred_device',data=mydata,palette='pastel')
# Out:
# <AxesSubplot:xlabel='preferred_device', ylabel='count'>

# %%
mydata['preferred_device'].value_counts(normalize=True)*100
# Out:
# 1.0    90.578231
# 0.0     9.421769
# Name: preferred_device, dtype: float64

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x = 'Taken_product', y = 'Daily_Avg_mins_spend_on_traveling_page', data = mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='Adult_flag',data=mydata)
# Out:
# <AxesSubplot:xlabel='Taken_product', ylabel='Adult_flag'>

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='travelling_network_rating',data=mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='week_since_last_outstation_checkin',data=mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='montly_avg_comment_on_company_page',data=mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='total_likes_on_outofstation_checkin_received',data=mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='Yearly_avg_comment_on_travel_page',data=mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='total_likes_on_outstation_checkin_given',data=mydata);

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Taken_product',y='Yearly_avg_view_on_travel_page',data=mydata);

# %%
mydata2 = mydata.select_dtypes(['object','category']) 
a = len(mydata2.columns) # number of rows 
b = 2 # number of columns 
c = 1 # initialize plot counter 
fig = plt.figure(figsize=(15,60))  

for i in mydata2.columns: 
    plt.subplot(a, b, c) 
    plt.xlabel(i,fontsize =10) 
    plt.xticks(rotation=90) 
    ax1 = sns.countplot(mydata2[i], hue=mydata['Taken_product']) 
    c = c + 1

# %%
sns.countplot(x='preferred_device',hue='Taken_product',data = mydata)
# Out:
# <AxesSubplot:xlabel='preferred_device', ylabel='count'>

# %%
plt.figure(figsize=(12,12))
sns.heatmap(mydata.corr(), annot=True, fmt='.2f', cmap='Blues');

# %%
mydata['preferred_device']=mydata['preferred_device'].astype('float64')
mydata.preferred_device.value_counts(dropna=False)
# Out:
# 1.0    10652
# 0.0     1108
# Name: preferred_device, dtype: int64

# %%
mydata['Taken_product'] = np.where(mydata['Taken_product']=='Yes',1,0) 
mydata['Taken_product'] = mydata['Taken_product'].astype('float64')

# %%
mydata['working_flag_lbl'] = np.where(mydata['working_flag']=='Yes',1,0) 
mydata['working_flag_lbl'] = mydata['working_flag_lbl'].astype('float64')

# %%
mydata['following_company_page_lbl'] = np.where(mydata['following_company_page']=='Yes',1,0) 
mydata['following_company_page_lbl'] = mydata['following_company_page_lbl'].astype('float64')

# %%
label = {'Beach':14,'Financial':13,'Historical site':12,'Medical':11,'Other':10,'Big Cities':9, 'Social media':8, 'Trekking':7, 'Entertainment':6, 'Hill Stations':5, 'Tour and Travel':4 ,'Game':3, 'OTT':2, 'Movie':1} 
mydata['preferred_location_type_lbl'] = mydata['preferred_location_type'].apply(lambda x: label [x]) 
mydata['preferred_location_type_lbl'] = mydata['preferred_location_type_lbl'].astype('float64')

# %%
mydata['member_in_family'] = mydata['member_in_family'].astype('float64') 
mydata['yearly_avg_Outstation_checkins'] = mydata['yearly_avg_Outstation_checkins'].astype('float64') 
mydata['Adult_flag'] = mydata['Adult_flag'].astype('float64')

# %%
mydata['travelling_network_rating'] = mydata['travelling_network_rating'].astype('category') 
mydata['travelling_network_rating'] = mydata['travelling_network_rating'].cat.set_categories([4.0,3.0,2.0,1.0])

# %%
print(mydata['Taken_product'].value_counts()) 
print('\n') 
print('Normalized Score is\n',mydata['Taken_product'].value_counts(normalize=True))
# Out:
# 0.0    9864
# 1.0    1896
# Name: Taken_product, dtype: int64
#
#
# Normalized Score is
#  0.0    0.838776
# 1.0    0.161224
# Name: Taken_product, dtype: float64

# %%
laptop=mydata.loc[mydata.preferred_device==0]

# %%
laptop.shape
# Out:
# (1108, 19)

# %%
mobile=mydata.loc[mydata.preferred_device==1]

# %%
mobile.shape
# Out:
# (10652, 19)

# %%
#outlier treatment

plt.figure(figsize=(20,8))
mydata.boxplot(rot=90);

# %%
 def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for column in mydata.columns: 
    if (mydata[column].dtype != 'O') : 
        mydata[column] = mydata[column].astype(int) 
        lr,ur = remove_outlier(mydata[column]) 
        mydata[column]=np.where(mydata[column]>ur,ur,mydata[column]) 
        mydata[column]=np.where(mydata[column]<lr,lr,mydata[column])

# %%
plt.figure(figsize=(20,8))
mydata.boxplot(rot=90);

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = StandardScaler()

# %%
scaled_df = X.fit_transform(mydata1)

# %%
scaled_df
# Out:
# array([[ 0.40077353,  0.32251825,  0.73519169, ..., -1.58417824,
#         -1.15309822, -0.64137356],
#        [ 1.30291384,  0.32251825, -1.30057234, ...,  1.19143799,
#          0.86722881, -0.42087298],
#        [-0.05029662,  0.32251825,  1.4055344 , ..., -0.65897283,
#         -1.15309822, -0.75162385],
#        ...,
#        [-0.99754395,  0.32251825, -1.60355169, ..., -0.65897283,
#          0.86722881, -0.2003724 ],
#        [ 1.52844891, -3.10059969,  0.54302914, ...,  1.19143799,
#         -1.15309822,  0.68162992],
#        [-0.15554633,  0.32251825, -0.43410933, ..., -1.58417824,
#         -1.15309822,  0.02012818]])

# %%
from sklearn.cluster import KMeans

# %%
k_means = KMeans(n_clusters = 2)

# %%
k_means.fit(mydata1)
# Out:
# KMeans(n_clusters=2)

# %%
k_means.labels_
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %%
k_means.inertia_
# Out:
# 947978976480.2196

# %%
k_means = KMeans(n_clusters = 3)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 89631.07077215913

# %%
k_means = KMeans(n_clusters = 4)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 79529.06740114168

# %%
k_means = KMeans(n_clusters = 1)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 117600.00000000006

# %%
k_means = KMeans(n_clusters = 5)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 70081.27044228776

# %%
k_means = KMeans(n_clusters = 6)
k_means.fit(scaled_df)
k_means.inertia_
# Out:
# 65110.553566975446

# %%
wss =[]

# %%
for i in range(1,11):
    KM = KMeans(n_clusters=i)
    KM.fit(scaled_df)
    wss.append(KM.inertia_)

# %%
wss
# Out:
# [117600.00000000006,
#  99908.76633417941,
#  90386.29134260838,
#  81440.54885440029,
#  71837.74564585445,
#  66123.62370544857,
#  61712.16087207793,
#  59029.76506836982,
#  57275.60680723763,
#  55282.71397426785]

# %%
plt.plot(range(1,11), wss)

# %%
from sklearn.metrics import silhouette_score

# %%
k_means = KMeans(n_clusters = 3)
k_means.fit(scaled_df)
labels = k_means.labels_

# %%
mydata["Clus_kmeans"] = labels
mydata.head(5)
# Out:
#    Taken_product  Yearly_avg_view_on_travel_page  preferred_device  \
# 0            0.0                           307.0               1.0
# 1            0.0                           367.0               1.0
# 2            0.0                           277.0               1.0
# 3            0.0                           247.0               1.0
# 4            0.0                           202.0               1.0
#
#    total_likes_on_outstation_checkin_given  yearly_avg_Outstation_checkins  \
# 0                                  38570.0                             1.0
# 1                                   9765.0                             1.0
# 2                                  48055.0                             1.0
# 3                                  48720.0                             1.0
# 4                                  20685.0                             1.0
#
#    member_in_family preferred_location_type  \
# 0               2.0               Financial
# ...

# %%
mydata.Clus_kmeans.value_counts().sort_index()
# Out:
# 0    2951
# 1    8618
# 2     191
# Name: Clus_kmeans, dtype: int64

# %%
from sklearn.decomposition import PCA
pca_3 = PCA(3)
plot_columns = pca_3.fit_transform(scaled_df)
plt.figure(figsize=(12,7))
sns.scatterplot(x=plot_columns[:,1], y=plot_columns[:,0], hue=KMeans(n_clusters=
3, random_state=0).fit(scaled_df).labels_, palette='Dark2_r',legend=False)
plt.title('Cluster Plot for 3 Clusters')
plt.show()

# %%
from sklearn.decomposition import PCA
pca_3 = PCA(3)
plot_columns = pca_3.fit_transform(scaled_df)
plt.figure(figsize=(12,7))
sns.scatterplot(x=plot_columns[:,1], y=plot_columns[:,0], hue=KMeans(n_clusters=
4, random_state=0).fit(scaled_df).labels_, palette='Dark2_r',legend=False)
plt.title('Cluster Plot for 4 Clusters')
plt.show()

# %%
clust_profile=mydata
clust_profile=clust_profile.groupby('Clus_kmeans').mean()
clust_profile['frequency']=mydata.Clus_kmeans.value_counts().sort_index()

# %%
clust_profile.head().T
# Out:
# Clus_kmeans                                              0             1  \
# Taken_product                                     0.000000      0.000000
# Yearly_avg_view_on_travel_page                  353.807015    255.452193
# preferred_device                                  1.000000      1.000000
# total_likes_on_outstation_checkin_given       28736.724331  27908.922662
# yearly_avg_Outstation_checkins                    8.264995      8.166280
# member_in_family                                  3.052863      2.873288
# Yearly_avg_comment_on_travel_page                77.002711     73.877118
# total_likes_on_outofstation_checkin_received  11716.905456   4564.600951
# week_since_last_outstation_checkin                4.619790      2.711302
# montly_avg_comment_on_company_page               23.231108     22.301114
# travelling_network_rating                         2.839715      2.671966
# Adult_flag                                        0.634361      0.548851
# ...

# %% [markdown]
# Laptop

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 5881 to 11758
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 1108 non-null   float64
#  1   Yearly_avg_view_on_travel_page                1108 non-null   float64
#  2   preferred_device                              1108 non-null   float64
#  3   total_likes_on_outstation_checkin_given       1108 non-null   float64
#  4   yearly_avg_Outstation_checkins                1108 non-null   float64
#  5   member_in_family                              1108 non-null   float64
#  6   preferred_location_type                       1108 non-null   object
#  7   Yearly_avg_comment_on_travel_page             1108 non-null   float64
#  8   total_likes_on_outofstation_checkin_received  1108 non-null   int64
# ...

# %%
laptop1 = laptop.drop(['preferred_location_type','following_company_page','working_flag'],axis=1)

# %%
laptop1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 5881 to 11758
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 1108 non-null   float64
#  1   Yearly_avg_view_on_travel_page                1108 non-null   float64
#  2   preferred_device                              1108 non-null   float64
#  3   total_likes_on_outstation_checkin_given       1108 non-null   float64
#  4   yearly_avg_Outstation_checkins                1108 non-null   float64
#  5   member_in_family                              1108 non-null   float64
#  6   Yearly_avg_comment_on_travel_page             1108 non-null   float64
#  7   total_likes_on_outofstation_checkin_received  1108 non-null   int64
#  8   week_since_last_outstation_checkin            1108 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
y = laptop1['Taken_product']
X = laptop1.drop('Taken_product',axis=1)

# %%
sc = StandardScaler()
X_fit = sc.fit_transform(X)
X = pd.DataFrame(X_fit,columns=X.columns)

# %%
 from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (775, 15)
# X_test (333, 15)
# y_train (775,)
# y_test (333,)

# %%
#Logistic Regression Basic Model

from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred_LR = model_LR.predict(X_train)
y_test_pred_LR = model_LR.predict(X_test)

# %%
sns.heatmap((confusion_matrix(y_train,y_train_pred_LR)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for Logistic Regression training set is\n',classification_report(y_train, y_train_pred_LR))
# Out:
# The classification report for Logistic Regression training set is
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.95      0.90       594
#          1.0       0.74      0.46      0.57       181
#
#     accuracy                           0.84       775
#    macro avg       0.80      0.71      0.74       775
# weighted avg       0.83      0.84      0.82       775

# %%
probs_LR_train = model_LR.predict_proba(X_train)
probs_LR_train = probs_LR_train[:,1]
auc_train = roc_auc_score(y_train, probs_LR_train)
print('The AUC score for Logistic Regression training set is: %.3f'%auc_train)
train_fpr_LR, train_tpr_LR, train_thresholds_LR = roc_curve(y_train, probs_LR_train);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(train_fpr_LR, train_tpr_LR);
# Out:
# The AUC score for Logistic Regression training set is: 0.817

# %%
sns.heatmap((confusion_matrix(y_test,y_test_pred_LR)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

print('The classification report for Logistic Regression testing set is\n',classification_report(y_test, y_test_pred_LR))
# Out:
# The classification report for Logistic Regression testing set is
#                precision    recall  f1-score   support
#
#          0.0       0.83      0.97      0.89       238
#          1.0       0.87      0.49      0.63        95
#
#     accuracy                           0.83       333
#    macro avg       0.85      0.73      0.76       333
# weighted avg       0.84      0.83      0.82       333

# %%
probs_LR_test = model_LR.predict_proba(X_test)
probs_LR_test = probs_LR_test[:,1]
auc_test = roc_auc_score(y_test, probs_LR_test)
print('The AUC score for Logistic Regression testing set is: %.3f'%auc_test)
test_fpr_LR, test_tpr_LR, test_thresholds_LR = roc_curve(y_test, probs_LR_test);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(test_fpr_LR, test_tpr_LR);
# Out:
# The AUC score for Logistic Regression testing set is: 0.865

# %%
#Log GridSearch

clf=LogisticRegression()
grid_values={'penalty':['l1','l2'],'C':[0.001,0.009,0.01,0.09,1,5,10,25],'solver':['newton-cg']}
model_LR=GridSearchCV(clf,param_grid=grid_values,cv=5)
model_LR.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.009, 0.01, 0.09, 1, 5, 10, 25],
#                          'penalty': ['l1', 'l2'], 'solver': ['newton-cg']})

# %%
model_LR.best_estimator_
# Out:
# LogisticRegression(C=1, solver='newton-cg')

# %%
best_grid=model_LR.best_estimator_

# %%
y_train_predict=best_grid.predict(X_train)
y_test_predict=best_grid.predict(X_test)

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8374193548387097
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.95      0.90       594
#          1.0       0.74      0.46      0.57       181
#
#     accuracy                           0.84       775
#    macro avg       0.80      0.71      0.74       775
# weighted avg       0.83      0.84      0.82       775

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.817

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8348348348348348
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.97      0.89       238
#          1.0       0.87      0.49      0.63        95
#
#     accuracy                           0.83       333
#    macro avg       0.85      0.73      0.76       333
# weighted avg       0.84      0.83      0.82       333

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.865

# %%
#KNN Basic

from sklearn.neighbors import KNeighborsClassifier
model_KNN = KNeighborsClassifier()
model_KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_train_pred_KNN = model_KNN.predict(X_train)
y_test_pred_KNN = model_KNN.predict(X_test)

# %%
sns.heatmap((confusion_matrix(y_train,y_train_pred_KNN)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for KNN set is\n',classification_report(y_train, y_train_pred_KNN))
# Out:
# The classification report for KNN set is
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98       594
#          1.0       0.96      0.87      0.91       181
#
#     accuracy                           0.96       775
#    macro avg       0.96      0.93      0.94       775
# weighted avg       0.96      0.96      0.96       775

# %%
probs_KNN_train = model_KNN.predict_proba(X_train)
probs_KNN_train = probs_KNN_train[:,1]
auc_train_KNN = roc_auc_score(y_train, probs_KNN_train)
print('The AUC score for KNN training set is: %.3f'%auc_train_KNN)
train_fpr_KNN, train_tpr_KNN, train_thresholds_KNN = roc_curve(y_train, probs_KNN_train);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(train_fpr_KNN, train_tpr_KNN);
# Out:
# The AUC score for KNN training set is: 0.991

# %%
sns.heatmap((confusion_matrix(y_test,y_test_pred_KNN)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for KNN testing set is\n',classification_report(y_test, y_test_pred_KNN))
# Out:
# The classification report for KNN testing set is
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.96      0.92       238
#          1.0       0.88      0.68      0.77        95
#
#     accuracy                           0.88       333
#    macro avg       0.88      0.82      0.85       333
# weighted avg       0.88      0.88      0.88       333

# %%
probs_KNN_test = model_KNN.predict_proba(X_test)
probs_KNN_test = probs_KNN_test[:,1]
auc_test_KNN = roc_auc_score(y_test, probs_KNN_test)
print('The AUC score for KNN testing set is: %.3f'%auc_test_KNN)
test_fpr_KNN, test_tpr_KNN, test_thresholds_KNN = roc_curve(y_test, probs_KNN_test);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(test_fpr_KNN, test_tpr_KNN);
# Out:
# The AUC score for KNN testing set is: 0.937

# %%
#KNN Grid Search

clf=KNeighborsClassifier()
param_grid={'leaf_size':[20,30,50],'n_neighbors':[10,20,30],'p':[1,2]}

model_KNN=GridSearchCV(clf,param_grid=param_grid,cv=5)
model_KNN.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'leaf_size': [20, 30, 50], 'n_neighbors': [10, 20, 30],
#                          'p': [1, 2]})

# %%
model_KNN.best_estimator_
best_grid=model_KNN.best_estimator_

# %%
y_train_predict=best_grid.predict(X_train)
y_test_predict=best_grid.predict(X_test)

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8658064516129033
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.99      0.92       594
#          1.0       0.95      0.45      0.61       181
#
#     accuracy                           0.87       775
#    macro avg       0.90      0.72      0.76       775
# weighted avg       0.88      0.87      0.85       775

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.964

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.7957957957957958
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.97      0.87       238
#          1.0       0.85      0.35      0.49        95
#
#     accuracy                           0.80       333
#    macro avg       0.82      0.66      0.68       333
# weighted avg       0.81      0.80      0.76       333

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.915

# %%
#Naive Bayes

from sklearn.naive_bayes import GaussianNB
model_NB = GaussianNB()
model_NB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_train_pred_NB = model_NB.predict(X_train)
y_test_pred_NB = model_NB.predict(X_test)

# %%
sns.heatmap((confusion_matrix(y_train,y_train_pred_NB)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for Naive Bayes Model set is\n',classification_report(y_train, y_train_pred_NB))
# Out:
# The classification report for Naive Bayes Model set is
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89       594
#          1.0       0.66      0.59      0.62       181
#
#     accuracy                           0.83       775
#    macro avg       0.77      0.75      0.76       775
# weighted avg       0.83      0.83      0.83       775

# %%
probs_NB_train = model_NB.predict_proba(X_train)
probs_NB_train = probs_NB_train[:,1]
auc_train_NB = roc_auc_score(y_train, probs_NB_train)
print('The AUC score for Naive Bayes training set is: %.3f'%auc_train_NB)
train_fpr_NB, train_tpr_NB, train_thresholds_NB = roc_curve(y_train, probs_NB_train);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(train_fpr_NB, train_tpr_NB);
# Out:
# The AUC score for Naive Bayes training set is: 0.809

# %%
print('The classification report for Naive bayes Model testing set is\n',classification_report(y_test, y_test_pred_NB))
sns.heatmap((confusion_matrix(y_test,y_test_pred_NB)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
# Out:
# The classification report for Naive bayes Model testing set is
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89       238
#          1.0       0.75      0.66      0.70        95
#
#     accuracy                           0.84       333
#    macro avg       0.81      0.79      0.80       333
# weighted avg       0.84      0.84      0.84       333

# %%
probs_NB_test = model_NB.predict_proba(X_test)
probs_NB_test = probs_NB_test[:,1]
auc_test_NB = roc_auc_score(y_test, probs_NB_test)
print('The AUC score for Naive Bayes testing set is: %.3f'%auc_test_NB)
test_fpr_NB, test_tpr_NB, test_thresholds_NB = roc_curve(y_test, probs_NB_test);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(test_fpr_NB, test_tpr_NB);
# Out:
# The AUC score for Naive Bayes testing set is: 0.850

# %%
#NB Grid Search

clf=GaussianNB()
grid_values={'var_smoothing':[1e-8,1e-7,1e-6,1e-5,1e-4]}
model_NB=GridSearchCV(clf,param_grid=grid_values,cv=5,n_jobs=1,verbose=2)
model_NB.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-06; total time=   0.0s
# ...

# %%
model_NB.best_estimator_
best_grid=model_NB.best_estimator_

# %%
y_train_predict=best_grid.predict(X_train)
y_test_predict=best_grid.predict(X_test)

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8335483870967741
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89       594
#          1.0       0.66      0.59      0.62       181
#
#     accuracy                           0.83       775
#    macro avg       0.77      0.75      0.76       775
# weighted avg       0.83      0.83      0.83       775

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.809

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8408408408408409
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.91      0.89       238
#          1.0       0.75      0.66      0.70        95
#
#     accuracy                           0.84       333
#    macro avg       0.81      0.79      0.80       333
# weighted avg       0.84      0.84      0.84       333

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.850

# %%
#Bagging Basic

from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
cart=RandomForestClassifier()
Bagging_Model=BaggingClassifier(base_estimator=cart,n_estimators=100,random_state=1)
Bagging_Model.fit(X_train,y_train)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=100,
#                   random_state=1)

# %%
#Train dataset

y_train_predict=Bagging_Model.predict(X_train)
model_score=Bagging_Model.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(Bagging_Model,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9987096774193548
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       594
#          1.0       1.00      0.99      1.00       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      1.00      1.00       775
# weighted avg       1.00      1.00      1.00       775

# %%
  #AUC and ROC for the training data
# predict probabilities
probs = Bagging_Model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=Bagging_Model.predict(X_test)
model_score=Bagging_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(Bagging_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9429429429429429
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96       238
#          1.0       1.00      0.80      0.89        95
#
#     accuracy                           0.94       333
#    macro avg       0.96      0.90      0.93       333
# weighted avg       0.95      0.94      0.94       333

# %%
# predict probabilities
probs = Bagging_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.998

# %%
#ADA Boost Basic

from sklearn.ensemble import AdaBoostClassifier
ADB_Model=AdaBoostClassifier(algorithm='SAMME.R',base_estimator=None,learning_rate=1.0,n_estimators=100,random_state=1)
ADB_Model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=1)

# %%
#Train dataset

y_train_predict=ADB_Model.predict(X_train)
model_score=ADB_Model.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(ADB_Model,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9458064516129032
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.97       594
#          1.0       0.97      0.79      0.87       181
#
#     accuracy                           0.95       775
#    macro avg       0.96      0.89      0.92       775
# weighted avg       0.95      0.95      0.94       775

# %%
 #AUC and ROC for the training data
# predict probabilities
probs = ADB_Model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.986

# %%
#Test dataset

y_test_predict=ADB_Model.predict(X_test)
model_score=ADB_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(ADB_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8708708708708709
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91       238
#          1.0       0.82      0.69      0.75        95
#
#     accuracy                           0.87       333
#    macro avg       0.86      0.82      0.83       333
# weighted avg       0.87      0.87      0.87       333

# %%
# predict probabilities
probs = ADB_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.926

# %%
#GBCL Basic

from sklearn.ensemble import GradientBoostingClassifier
GBCL_Model = GradientBoostingClassifier(random_state=1)
GBCL_Model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
#Train dataset

y_train_predict=GBCL_Model.predict(X_train)
model_score=GBCL_Model.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(GBCL_Model,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9858064516129033
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       594
#          1.0       1.00      0.94      0.97       181
#
#     accuracy                           0.99       775
#    macro avg       0.99      0.97      0.98       775
# weighted avg       0.99      0.99      0.99       775

# %%
 #AUC and ROC for the training data
# predict probabilities
probs = GBCL_Model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.999

# %%
#Test dataset

y_test_predict=GBCL_Model.predict(X_test)
model_score=GBCL_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(GBCL_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9579579579579579
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       238
#          1.0       1.00      0.85      0.92        95
#
#     accuracy                           0.96       333
#    macro avg       0.97      0.93      0.95       333
# weighted avg       0.96      0.96      0.96       333

# %%
# predict probabilities
probs = GBCL_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.991

# %%
#Bagging Grid Search

grid={'max_samples':[0.5,1.0],'max_features':[1,2,4],'bootstrap':[True,False]}
rfcl=BaggingClassifier(base_estimator=RandomForestClassifier(),n_estimators=100,random_state=1)
grid_search=GridSearchCV(estimator=rfcl,param_grid=grid,cv=3)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=BaggingClassifier(base_estimator=RandomForestClassifier(),
#                                          n_estimators=100, random_state=1),
#              param_grid={'bootstrap': [True, False], 'max_features': [1, 2, 4],
#                          'max_samples': [0.5, 1.0]})

# %%
grid_search.best_estimator_
best_grid=grid_search.best_estimator_

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       594
#          1.0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      1.00      1.00       775
# weighted avg       1.00      1.00      1.00       775

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8918918918918919
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93       238
#          1.0       1.00      0.62      0.77        95
#
#     accuracy                           0.89       333
#    macro avg       0.93      0.81      0.85       333
# weighted avg       0.91      0.89      0.88       333

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.998

# %%
#ADA Boost Grid Search

ada=AdaBoostClassifier()
search_grid={'n_estimators':[500,1000,2000],'learning_rate':[0.001,0.01,0.1]}
ADB_Model=GridSearchCV(estimator=ada,param_grid=search_grid,n_jobs=1,cv=3)

# %%
ADB_Model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [500, 1000, 2000]})

# %%
ADB_Model.best_estimator_
best_grid=ADB_Model.best_estimator_

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9548387096774194
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97       594
#          1.0       0.96      0.84      0.90       181
#
#     accuracy                           0.95       775
#    macro avg       0.96      0.91      0.93       775
# weighted avg       0.96      0.95      0.95       775

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.992

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8798798798798799
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92       238
#          1.0       0.84      0.72      0.77        95
#
#     accuracy                           0.88       333
#    macro avg       0.87      0.83      0.85       333
# weighted avg       0.88      0.88      0.88       333

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.948

# %%
#Gradient Boosting Grid Search

grid={'n_estimators':range(1000,2000,3000)}
model=GradientBoostingClassifier()
grid_search=GridSearchCV(estimator=model,param_grid=grid,cv=3)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(),
#              param_grid={'n_estimators': range(1000, 2000, 3000)})

# %%
grid_search.best_estimator_
best_grid=grid_search.best_estimator_

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       594
#          1.0       1.00      1.00      1.00       181
#
#     accuracy                           1.00       775
#    macro avg       1.00      1.00      1.00       775
# weighted avg       1.00      1.00      1.00       775

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.987987987987988
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       238
#          1.0       1.00      0.96      0.98        95
#
#     accuracy                           0.99       333
#    macro avg       0.99      0.98      0.99       333
# weighted avg       0.99      0.99      0.99       333

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 1.000

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())

# %%
X_train_res.shape
# Out:
# (1188, 15)

# %%
# Log SMOTE

LOG_SM_Model=LogisticRegression(max_iter=10000,n_jobs=2)
LOG_SM_Model.fit(X_train_res,y_train_res)
# Out:
# LogisticRegression(max_iter=10000, n_jobs=2)

# %%
y_train_predict=LOG_SM_Model.predict(X_train_res)
model_score=LOG_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(LOG_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.7432659932659933
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.75      0.74       594
#          1.0       0.74      0.74      0.74       594
#
#     accuracy                           0.74      1188
#    macro avg       0.74      0.74      0.74      1188
# weighted avg       0.74      0.74      0.74      1188

# %%
#AUC and ROC for the training data
# predict probabilities
probs = LOG_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.821

# %%
#Test dataset

y_test_predict=LOG_SM_Model.predict(X_test)
model_score=LOG_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(LOG_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.7297297297297297
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.70      0.79       238
#          1.0       0.52      0.80      0.63        95
#
#     accuracy                           0.73       333
#    macro avg       0.71      0.75      0.71       333
# weighted avg       0.79      0.73      0.74       333

# %%
# predict probabilities
probs = LOG_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.857

# %%
#KNN SMOTE

from sklearn.neighbors import KNeighborsClassifier

KNN_SM_Model=KNeighborsClassifier()
KNN_SM_Model.fit(X_train_res,y_train_res)
# Out:
# KNeighborsClassifier()

# %%
y_train_predict=KNN_SM_Model.predict(X_train_res)
model_score=KNN_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(KNN_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.9865319865319865
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.99       594
#          1.0       0.98      1.00      0.99       594
#
#     accuracy                           0.99      1188
#    macro avg       0.99      0.99      0.99      1188
# weighted avg       0.99      0.99      0.99      1188

# %%
#AUC and ROC for the training data
# predict probabilities
probs = KNN_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=KNN_SM_Model.predict(X_test)
model_score=KNN_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(KNN_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9129129129129129
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.91      0.94       238
#          1.0       0.81      0.92      0.86        95
#
#     accuracy                           0.91       333
#    macro avg       0.89      0.91      0.90       333
# weighted avg       0.92      0.91      0.91       333

# %%
# predict probabilities
probs = KNN_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.956

# %%
#NB SMOTE

from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
NB_SM_Model = GaussianNB()
NB_SM_Model.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_train_predict=NB_SM_Model.predict(X_train_res)
model_score=NB_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(NB_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.7138047138047138
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.60      0.68       594
#          1.0       0.67      0.83      0.74       594
#
#     accuracy                           0.71      1188
#    macro avg       0.73      0.71      0.71      1188
# weighted avg       0.73      0.71      0.71      1188

# %%
#AUC and ROC for the training data
# predict probabilities
probs = NB_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.806

# %%
#Test dataset

y_test_predict=NB_SM_Model.predict(X_test)
model_score=NB_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(NB_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.6546546546546547
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.59      0.71       238
#          1.0       0.44      0.82      0.58        95
#
#     accuracy                           0.65       333
#    macro avg       0.67      0.70      0.64       333
# weighted avg       0.76      0.65      0.67       333

# %%
# predict probabilities
probs = NB_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.840

# %%
#Bagging SMOTE

cart=RandomForestClassifier()
Bag_SM_Model = BaggingClassifier(base_estimator=cart,n_estimators=100,random_state=1)
Bag_SM_Model.fit(X_train_res, y_train_res)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=100,
#                   random_state=1)

# %%
y_train_predict=Bag_SM_Model.predict(X_train_res)
model_score=Bag_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(Bag_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       594
#          1.0       1.00      1.00      1.00       594
#
#     accuracy                           1.00      1188
#    macro avg       1.00      1.00      1.00      1188
# weighted avg       1.00      1.00      1.00      1188

# %%
#AUC and ROC for the training data
# predict probabilities
probs = Bag_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=Bag_SM_Model.predict(X_test)
model_score=Bag_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(Bag_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.978978978978979
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.99       238
#          1.0       0.96      0.97      0.96        95
#
#     accuracy                           0.98       333
#    macro avg       0.97      0.98      0.97       333
# weighted avg       0.98      0.98      0.98       333

# %%
# predict probabilities
probs = Bag_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.998

# %%
#ADA Boosting SMOTE

ADB_SM_Model = AdaBoostClassifier(n_estimators=100,random_state=1)
ADB_SM_Model.fit(X_train_res, y_train_res)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=1)

# %%
y_train_predict=ADB_SM_Model.predict(X_train_res)
model_score=ADB_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(ADB_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.9225589225589226
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.92      0.92       594
#          1.0       0.92      0.93      0.92       594
#
#     accuracy                           0.92      1188
#    macro avg       0.92      0.92      0.92      1188
# weighted avg       0.92      0.92      0.92      1188

# %%
#AUC and ROC for the training data
# predict probabilities
probs =ADB_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.983

# %%
#Test dataset

y_test_predict=ADB_SM_Model.predict(X_test)
model_score=ADB_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(ADB_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8318318318318318
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.83      0.88       238
#          1.0       0.66      0.83      0.74        95
#
#     accuracy                           0.83       333
#    macro avg       0.79      0.83      0.81       333
# weighted avg       0.85      0.83      0.84       333

# %%
# predict probabilities
probs = ADB_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.932

# %%
#Gradient Boosting SMOTE


GB_SM_Model = GradientBoostingClassifier(n_estimators=100,random_state=1)
GB_SM_Model.fit(X_train_res, y_train_res)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
y_train_predict=GB_SM_Model.predict(X_train_res)
model_score=GB_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(GB_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.9915824915824916
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99       594
#          1.0       0.99      1.00      0.99       594
#
#     accuracy                           0.99      1188
#    macro avg       0.99      0.99      0.99      1188
# weighted avg       0.99      0.99      0.99      1188

# %%
#AUC and ROC for the training data
# predict probabilities
probs =GB_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.999

# %%
#Test dataset

y_test_predict=GB_SM_Model.predict(X_test)
model_score=GB_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(GB_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.954954954954955
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.95      0.97       238
#          1.0       0.88      0.97      0.92        95
#
#     accuracy                           0.95       333
#    macro avg       0.94      0.96      0.95       333
# weighted avg       0.96      0.95      0.96       333

# %%
# predict probabilities
probs = GB_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.990

# %% [markdown]
# MOBILE Data

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10652 entries, 0 to 11759
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 10652 non-null  float64
#  1   Yearly_avg_view_on_travel_page                10652 non-null  float64
#  2   preferred_device                              10652 non-null  float64
#  3   total_likes_on_outstation_checkin_given       10652 non-null  float64
#  4   yearly_avg_Outstation_checkins                10652 non-null  float64
#  5   member_in_family                              10652 non-null  float64
#  6   preferred_location_type                       10652 non-null  object
#  7   Yearly_avg_comment_on_travel_page             10652 non-null  float64
#  8   total_likes_on_outofstation_checkin_received  10652 non-null  int64
# ...

# %%
mobile1 = mobile.drop(['preferred_location_type','following_company_page','working_flag'],axis=1)

# %%
mobile1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10652 entries, 0 to 11759
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Taken_product                                 10652 non-null  float64
#  1   Yearly_avg_view_on_travel_page                10652 non-null  float64
#  2   preferred_device                              10652 non-null  float64
#  3   total_likes_on_outstation_checkin_given       10652 non-null  float64
#  4   yearly_avg_Outstation_checkins                10652 non-null  float64
#  5   member_in_family                              10652 non-null  float64
#  6   Yearly_avg_comment_on_travel_page             10652 non-null  float64
#  7   total_likes_on_outofstation_checkin_received  10652 non-null  int64
#  8   week_since_last_outstation_checkin            10652 non-null  int64
# ...

# %%
y = mobile1['Taken_product']
X = mobile1.drop('Taken_product',axis=1)

# %%
sc = StandardScaler()
X_fit = sc.fit_transform(X)
X = pd.DataFrame(X_fit,columns=X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print('X_train',X_train.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# X_train (7456, 15)
# X_test (3196, 15)
# y_train (7456,)
# y_test (3196,)

# %%
#Logistic Regression Basic Model

from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred_LR = model_LR.predict(X_train)
y_test_pred_LR = model_LR.predict(X_test)

# %%
sns.heatmap((confusion_matrix(y_train,y_train_pred_LR)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for Logistic Regression training set is\n',classification_report(y_train, y_train_pred_LR))
# Out:
# The classification report for Logistic Regression training set is
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.99      0.93      6330
#          1.0       0.71      0.20      0.31      1126
#
#     accuracy                           0.87      7456
#    macro avg       0.79      0.59      0.62      7456
# weighted avg       0.85      0.87      0.83      7456

# %%
probs_LR_train = model_LR.predict_proba(X_train)
probs_LR_train = probs_LR_train[:,1]
auc_train = roc_auc_score(y_train, probs_LR_train)
print('The AUC score for Logistic Regression training set is: %.3f'%auc_train)
train_fpr_LR, train_tpr_LR, train_thresholds_LR = roc_curve(y_train, probs_LR_train);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(train_fpr_LR, train_tpr_LR);
# Out:
# The AUC score for Logistic Regression training set is: 0.786

# %%
sns.heatmap((confusion_matrix(y_test,y_test_pred_LR)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

print('The classification report for Logistic Regression testing set is\n',classification_report(y_test, y_test_pred_LR))
# Out:
# The classification report for Logistic Regression testing set is
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93      2702
#          1.0       0.74      0.23      0.35       494
#
#     accuracy                           0.87      3196
#    macro avg       0.81      0.61      0.64      3196
# weighted avg       0.85      0.87      0.84      3196

# %%
probs_LR_test = model_LR.predict_proba(X_test)
probs_LR_test = probs_LR_test[:,1]
auc_test = roc_auc_score(y_test, probs_LR_test)
print('The AUC score for Logistic Regression testing set is: %.3f'%auc_test)
test_fpr_LR, test_tpr_LR, test_thresholds_LR = roc_curve(y_test, probs_LR_test);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(test_fpr_LR, test_tpr_LR);
# Out:
# The AUC score for Logistic Regression testing set is: 0.798

# %%
#Log GridSearch

clf=LogisticRegression()
grid_values={'penalty':['l1','l2'],'C':[0.001,0.009,0.01,0.09,1,5,10,25],'solver':['newton-cg']}
model_LR=GridSearchCV(clf,param_grid=grid_values,cv=5)
model_LR.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.009, 0.01, 0.09, 1, 5, 10, 25],
#                          'penalty': ['l1', 'l2'], 'solver': ['newton-cg']})

# %%
model_LR.best_estimator_
# Out:
# LogisticRegression(C=0.09, solver='newton-cg')

# %%
best_grid=model_LR.best_estimator_

# %%
y_train_predict=best_grid.predict(X_train)
y_test_predict=best_grid.predict(X_test)

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8672210300429185
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.99      0.93      6330
#          1.0       0.72      0.20      0.31      1126
#
#     accuracy                           0.87      7456
#    macro avg       0.80      0.59      0.62      7456
# weighted avg       0.85      0.87      0.83      7456

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.786

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8679599499374218
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.99      0.93      2702
#          1.0       0.74      0.23      0.35       494
#
#     accuracy                           0.87      3196
#    macro avg       0.81      0.61      0.64      3196
# weighted avg       0.85      0.87      0.84      3196

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.798

# %%
#KNN Basic

from sklearn.neighbors import KNeighborsClassifier
model_KNN = KNeighborsClassifier()
model_KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_train_pred_KNN = model_KNN.predict(X_train)
y_test_pred_KNN = model_KNN.predict(X_test)

# %%
sns.heatmap((confusion_matrix(y_train,y_train_pred_KNN)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for KNN set is\n',classification_report(y_train, y_train_pred_KNN))
# Out:
# The classification report for KNN set is
#                precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6330
#          1.0       0.98      0.93      0.95      1126
#
#     accuracy                           0.99      7456
#    macro avg       0.98      0.96      0.97      7456
# weighted avg       0.99      0.99      0.99      7456

# %%
probs_KNN_train = model_KNN.predict_proba(X_train)
probs_KNN_train = probs_KNN_train[:,1]
auc_train_KNN = roc_auc_score(y_train, probs_KNN_train)
print('The AUC score for KNN training set is: %.3f'%auc_train_KNN)
train_fpr_KNN, train_tpr_KNN, train_thresholds_KNN = roc_curve(y_train, probs_KNN_train);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(train_fpr_KNN, train_tpr_KNN);
# Out:
# The AUC score for KNN training set is: 0.999

# %%
sns.heatmap((confusion_matrix(y_test,y_test_pred_KNN)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for KNN testing set is\n',classification_report(y_test, y_test_pred_KNN))
# Out:
# The classification report for KNN testing set is
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.98      2702
#          1.0       0.95      0.86      0.90       494
#
#     accuracy                           0.97      3196
#    macro avg       0.96      0.93      0.94      3196
# weighted avg       0.97      0.97      0.97      3196

# %%
probs_KNN_test = model_KNN.predict_proba(X_test)
probs_KNN_test = probs_KNN_test[:,1]
auc_test_KNN = roc_auc_score(y_test, probs_KNN_test)
print('The AUC score for KNN testing set is: %.3f'%auc_test_KNN)
test_fpr_KNN, test_tpr_KNN, test_thresholds_KNN = roc_curve(y_test, probs_KNN_test);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(test_fpr_KNN, test_tpr_KNN);
# Out:
# The AUC score for KNN testing set is: 0.988

# %%
#KNN Grid Search

clf=KNeighborsClassifier()
param_grid={'leaf_size':[20,30,50],'n_neighbors':[10,20,30],'p':[1,2]}

model_KNN=GridSearchCV(clf,param_grid=param_grid,cv=5)
model_KNN.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'leaf_size': [20, 30, 50], 'n_neighbors': [10, 20, 30],
#                          'p': [1, 2]})

# %%
model_KNN.best_estimator_
best_grid=model_KNN.best_estimator_

# %%
y_train_predict=best_grid.predict(X_train)
y_test_predict=best_grid.predict(X_test)

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9475590128755365
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      6330
#          1.0       0.98      0.67      0.79      1126
#
#     accuracy                           0.95      7456
#    macro avg       0.96      0.83      0.88      7456
# weighted avg       0.95      0.95      0.94      7456

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.991

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9180225281602002
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95      2702
#          1.0       0.94      0.50      0.66       494
#
#     accuracy                           0.92      3196
#    macro avg       0.93      0.75      0.80      3196
# weighted avg       0.92      0.92      0.91      3196

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.973

# %%
#Naive Bayes

from sklearn.naive_bayes import GaussianNB
model_NB = GaussianNB()
model_NB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_train_pred_NB = model_NB.predict(X_train)
y_test_pred_NB = model_NB.predict(X_test)

# %%
sns.heatmap((confusion_matrix(y_train,y_train_pred_NB)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
print('The classification report for Naive Bayes Model set is\n',classification_report(y_train, y_train_pred_NB))
# Out:
# The classification report for Naive Bayes Model set is
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.96      0.92      6330
#          1.0       0.56      0.28      0.37      1126
#
#     accuracy                           0.86      7456
#    macro avg       0.72      0.62      0.65      7456
# weighted avg       0.83      0.86      0.84      7456

# %%
probs_NB_train = model_NB.predict_proba(X_train)
probs_NB_train = probs_NB_train[:,1]
auc_train_NB = roc_auc_score(y_train, probs_NB_train)
print('The AUC score for Naive Bayes training set is: %.3f'%auc_train_NB)
train_fpr_NB, train_tpr_NB, train_thresholds_NB = roc_curve(y_train, probs_NB_train);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(train_fpr_NB, train_tpr_NB);
# Out:
# The AUC score for Naive Bayes training set is: 0.765

# %%
print('The classification report for Naive bayes Model testing set is\n',classification_report(y_test, y_test_pred_NB))
sns.heatmap((confusion_matrix(y_test,y_test_pred_NB)),annot=True,fmt='.5g',cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);
# Out:
# The classification report for Naive bayes Model testing set is
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.92      2702
#          1.0       0.53      0.31      0.39       494
#
#     accuracy                           0.85      3196
#    macro avg       0.71      0.63      0.65      3196
# weighted avg       0.83      0.85      0.83      3196

# %%
probs_NB_test = model_NB.predict_proba(X_test)
probs_NB_test = probs_NB_test[:,1]
auc_test_NB = roc_auc_score(y_test, probs_NB_test)
print('The AUC score for Naive Bayes testing set is: %.3f'%auc_test_NB)
test_fpr_NB, test_tpr_NB, test_thresholds_NB = roc_curve(y_test, probs_NB_test);
plt.plot([0,1],[0,1], linestyle = '--');
plt.plot(test_fpr_NB, test_tpr_NB);
# Out:
# The AUC score for Naive Bayes testing set is: 0.774

# %%
#NB Grid Search

clf=GaussianNB()
grid_values={'var_smoothing':[1e-8,1e-7,1e-6,1e-5,1e-4]}
model_NB=GridSearchCV(clf,param_grid=grid_values,cv=5,n_jobs=1,verbose=2)
model_NB.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-08; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-07; total time=   0.0s
# [CV] END ................................var_smoothing=1e-06; total time=   0.0s
# ...

# %%
model_NB.best_estimator_
best_grid=model_NB.best_estimator_

# %%
y_train_predict=best_grid.predict(X_train)
y_test_predict=best_grid.predict(X_test)

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8575643776824035
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.96      0.92      6330
#          1.0       0.56      0.28      0.37      1126
#
#     accuracy                           0.86      7456
#    macro avg       0.72      0.62      0.65      7456
# weighted avg       0.83      0.86      0.84      7456

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.765

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8507509386733417
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.92      2702
#          1.0       0.53      0.31      0.39       494
#
#     accuracy                           0.85      3196
#    macro avg       0.71      0.63      0.65      3196
# weighted avg       0.83      0.85      0.83      3196

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.774

# %%
#Bagging Basic

from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
cart=RandomForestClassifier()
Bagging_Model=BaggingClassifier(base_estimator=cart,n_estimators=100,random_state=1)
Bagging_Model.fit(X_train,y_train)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=100,
#                   random_state=1)

# %%
#Train dataset

y_train_predict=Bagging_Model.predict(X_train)
model_score=Bagging_Model.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(Bagging_Model,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.998524678111588
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6330
#          1.0       1.00      0.99      1.00      1126
#
#     accuracy                           1.00      7456
#    macro avg       1.00      1.00      1.00      7456
# weighted avg       1.00      1.00      1.00      7456

# %%
  #AUC and ROC for the training data
# predict probabilities
probs = Bagging_Model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=Bagging_Model.predict(X_test)
model_score=Bagging_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(Bagging_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9637046307884856
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      2702
#          1.0       1.00      0.77      0.87       494
#
#     accuracy                           0.96      3196
#    macro avg       0.98      0.88      0.92      3196
# weighted avg       0.97      0.96      0.96      3196

# %%
# predict probabilities
probs = Bagging_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.998

# %%
#ADA Boost Basic

from sklearn.ensemble import AdaBoostClassifier
ADB_Model=AdaBoostClassifier(algorithm='SAMME.R',base_estimator=None,learning_rate=1.0,n_estimators=100,random_state=1)
ADB_Model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=1)

# %%
#Train dataset

y_train_predict=ADB_Model.predict(X_train)
model_score=ADB_Model.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(ADB_Model,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8807671673819742
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.98      0.93      6330
#          1.0       0.73      0.33      0.46      1126
#
#     accuracy                           0.88      7456
#    macro avg       0.81      0.66      0.70      7456
# weighted avg       0.87      0.88      0.86      7456

# %%
 #AUC and ROC for the training data
# predict probabilities
probs = ADB_Model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.877

# %%
#Test dataset

y_test_predict=ADB_Model.predict(X_test)
model_score=ADB_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(ADB_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8811013767209012
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.97      0.93      2702
#          1.0       0.71      0.39      0.50       494
#
#     accuracy                           0.88      3196
#    macro avg       0.80      0.68      0.72      3196
# weighted avg       0.87      0.88      0.87      3196

# %%
# predict probabilities
probs = ADB_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.861

# %%
#GBCL Basic

from sklearn.ensemble import GradientBoostingClassifier
GBCL_Model = GradientBoostingClassifier(random_state=1)
GBCL_Model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
#Train dataset

y_train_predict=GBCL_Model.predict(X_train)
model_score=GBCL_Model.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(GBCL_Model,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9138948497854077
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.95      6330
#          1.0       0.91      0.48      0.63      1126
#
#     accuracy                           0.91      7456
#    macro avg       0.91      0.73      0.79      7456
# weighted avg       0.91      0.91      0.90      7456

# %%
 #AUC and ROC for the training data
# predict probabilities
probs = GBCL_Model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.939

# %%
#Test dataset

y_test_predict=GBCL_Model.predict(X_test)
model_score=GBCL_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(GBCL_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9023779724655819
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.99      0.94      2702
#          1.0       0.88      0.43      0.57       494
#
#     accuracy                           0.90      3196
#    macro avg       0.89      0.71      0.76      3196
# weighted avg       0.90      0.90      0.89      3196

# %%
# predict probabilities
probs = GBCL_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.915

# %%
#Bagging Grid Search

grid={'max_samples':[0.5,1.0],'max_features':[1,2,4],'bootstrap':[True,False]}
rfcl=BaggingClassifier(base_estimator=RandomForestClassifier(),n_estimators=100,random_state=1)
grid_search=GridSearchCV(estimator=rfcl,param_grid=grid,cv=3)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=BaggingClassifier(base_estimator=RandomForestClassifier(),
#                                          n_estimators=100, random_state=1),
#              param_grid={'bootstrap': [True, False], 'max_features': [1, 2, 4],
#                          'max_samples': [0.5, 1.0]})

# %%
grid_search.best_estimator_
best_grid=grid_search.best_estimator_

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9974517167381974
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6330
#          1.0       1.00      0.98      0.99      1126
#
#     accuracy                           1.00      7456
#    macro avg       1.00      0.99      0.99      7456
# weighted avg       1.00      1.00      1.00      7456

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8983103879849812
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94      2702
#          1.0       1.00      0.34      0.51       494
#
#     accuracy                           0.90      3196
#    macro avg       0.95      0.67      0.73      3196
# weighted avg       0.91      0.90      0.88      3196

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.999

# %%
#ADA Boost Grid Search

ada=AdaBoostClassifier()
search_grid={'n_estimators':[500,1000,2000],'learning_rate':[0.001,0.01,0.1]}
ADB_Model=GridSearchCV(estimator=ada,param_grid=search_grid,n_jobs=1,cv=3)

# %%
ADB_Model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(), n_jobs=1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [500, 1000, 2000]})

# %%
ADB_Model.best_estimator_
best_grid=ADB_Model.best_estimator_

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.8862660944206009
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.98      0.94      6330
#          1.0       0.78      0.34      0.48      1126
#
#     accuracy                           0.89      7456
#    macro avg       0.84      0.66      0.71      7456
# weighted avg       0.88      0.89      0.87      7456

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.883

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8829787234042553
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.98      0.93      2702
#          1.0       0.74      0.37      0.50       494
#
#     accuracy                           0.88      3196
#    macro avg       0.82      0.68      0.72      3196
# weighted avg       0.87      0.88      0.87      3196

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.872

# %%
#Gradient Boosting Grid Search

grid={'n_estimators':range(1000,2000,3000)}
model=GradientBoostingClassifier()
grid_search=GridSearchCV(estimator=model,param_grid=grid,cv=3)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(),
#              param_grid={'n_estimators': range(1000, 2000, 3000)})

# %%
grid_search.best_estimator_
best_grid=grid_search.best_estimator_

# %%
#Train dataset

y_train_predict=best_grid.predict(X_train)
model_score=best_grid.score(X_train,y_train)
print(model_score)
plot_confusion_matrix(best_grid,X_train,y_train)
print(classification_report(y_train, y_train_predict),'\n');
# Out:
# 0.9970493562231759
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6330
#          1.0       1.00      0.98      0.99      1126
#
#     accuracy                           1.00      7456
#    macro avg       1.00      0.99      0.99      7456
# weighted avg       1.00      1.00      1.00      7456

# %%
#AUC and ROC for the training data
# predict probabilities
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=best_grid.predict(X_test)
model_score=best_grid.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(best_grid,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9690237797246558
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      2702
#          1.0       0.98      0.82      0.89       494
#
#     accuracy                           0.97      3196
#    macro avg       0.97      0.91      0.94      3196
# weighted avg       0.97      0.97      0.97      3196

# %%
# predict probabilities
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.995

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())

# %%
X_train_res.shape
# Out:
# (12660, 15)

# %%
# Log SMOTE

LOG_SM_Model=LogisticRegression(max_iter=10000,n_jobs=2)
LOG_SM_Model.fit(X_train_res,y_train_res)
# Out:
# LogisticRegression(max_iter=10000, n_jobs=2)

# %%
y_train_predict=LOG_SM_Model.predict(X_train_res)
model_score=LOG_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(LOG_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.725829383886256
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.72      0.72      6330
#          1.0       0.72      0.73      0.73      6330
#
#     accuracy                           0.73     12660
#    macro avg       0.73      0.73      0.73     12660
# weighted avg       0.73      0.73      0.73     12660

# %%
#AUC and ROC for the training data
# predict probabilities
probs = LOG_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.788

# %%
#Test dataset

y_test_predict=LOG_SM_Model.predict(X_test)
model_score=LOG_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(LOG_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.7130788485607009
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.70      0.81      2702
#          1.0       0.32      0.76      0.45       494
#
#     accuracy                           0.71      3196
#    macro avg       0.63      0.73      0.63      3196
# weighted avg       0.85      0.71      0.75      3196

# %%
# predict probabilities
probs = LOG_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.794

# %%
#KNN SMOTE

from sklearn.neighbors import KNeighborsClassifier

KNN_SM_Model=KNeighborsClassifier()
KNN_SM_Model.fit(X_train_res,y_train_res)
# Out:
# KNeighborsClassifier()

# %%
y_train_predict=KNN_SM_Model.predict(X_train_res)
model_score=KNN_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(KNN_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.9922590837282781
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99      6330
#          1.0       0.99      1.00      0.99      6330
#
#     accuracy                           0.99     12660
#    macro avg       0.99      0.99      0.99     12660
# weighted avg       0.99      0.99      0.99     12660

# %%
#AUC and ROC for the training data
# predict probabilities
probs = KNN_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=KNN_SM_Model.predict(X_test)
model_score=KNN_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(KNN_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.9705882352941176
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.98      2702
#          1.0       0.85      0.98      0.91       494
#
#     accuracy                           0.97      3196
#    macro avg       0.92      0.97      0.95      3196
# weighted avg       0.97      0.97      0.97      3196

# %%
# predict probabilities
probs = KNN_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.991

# %%
#NB SMOTE

from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
NB_SM_Model = GaussianNB()
NB_SM_Model.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_train_predict=NB_SM_Model.predict(X_train_res)
model_score=NB_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(NB_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.6844391785150079
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.65      0.67      6330
#          1.0       0.67      0.72      0.70      6330
#
#     accuracy                           0.68     12660
#    macro avg       0.69      0.68      0.68     12660
# weighted avg       0.69      0.68      0.68     12660

# %%
#AUC and ROC for the training data
# predict probabilities
probs = NB_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.765

# %%
#Test dataset

y_test_predict=NB_SM_Model.predict(X_test)
model_score=NB_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(NB_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.6595744680851063
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.64      0.76      2702
#          1.0       0.28      0.75      0.40       494
#
#     accuracy                           0.66      3196
#    macro avg       0.60      0.70      0.58      3196
# weighted avg       0.83      0.66      0.71      3196

# %%
# predict probabilities
probs = NB_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.770

# %%
#Bagging SMOTE

cart=RandomForestClassifier()
Bag_SM_Model = BaggingClassifier(base_estimator=cart,n_estimators=100,random_state=1)
Bag_SM_Model.fit(X_train_res, y_train_res)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=100,
#                   random_state=1)

# %%
y_train_predict=Bag_SM_Model.predict(X_train_res)
model_score=Bag_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(Bag_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6330
#          1.0       1.00      1.00      1.00      6330
#
#     accuracy                           1.00     12660
#    macro avg       1.00      1.00      1.00     12660
# weighted avg       1.00      1.00      1.00     12660

# %%
#AUC and ROC for the training data
# predict probabilities
probs = Bag_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 1.000

# %%
#Test dataset

y_test_predict=Bag_SM_Model.predict(X_test)
model_score=Bag_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(Bag_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.981226533166458
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      2702
#          1.0       0.96      0.92      0.94       494
#
#     accuracy                           0.98      3196
#    macro avg       0.97      0.95      0.96      3196
# weighted avg       0.98      0.98      0.98      3196

# %%
# predict probabilities
probs = Bag_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.998

# %%
#ADA Boosting SMOTE

ADB_SM_Model = AdaBoostClassifier(n_estimators=100,random_state=1)
ADB_SM_Model.fit(X_train_res, y_train_res)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=1)

# %%
y_train_predict=ADB_SM_Model.predict(X_train_res)
model_score=ADB_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(ADB_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.8409162717219589
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.85      0.84      6330
#          1.0       0.85      0.83      0.84      6330
#
#     accuracy                           0.84     12660
#    macro avg       0.84      0.84      0.84     12660
# weighted avg       0.84      0.84      0.84     12660

# %%
#AUC and ROC for the training data
# predict probabilities
probs =ADB_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.926

# %%
#Test dataset

y_test_predict=ADB_SM_Model.predict(X_test)
model_score=ADB_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(ADB_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8169586983729662
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.85      0.89      2702
#          1.0       0.44      0.64      0.52       494
#
#     accuracy                           0.82      3196
#    macro avg       0.68      0.75      0.70      3196
# weighted avg       0.85      0.82      0.83      3196

# %%
# predict probabilities
probs = ADB_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.845

# %%
#Gradient Boosting SMOTE


GB_SM_Model = GradientBoostingClassifier(n_estimators=100,random_state=1)
GB_SM_Model.fit(X_train_res, y_train_res)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
y_train_predict=GB_SM_Model.predict(X_train_res)
model_score=GB_SM_Model.score(X_train_res,y_train_res)
print(model_score)
plot_confusion_matrix(GB_SM_Model,X_train_res,y_train_res)
print(classification_report(y_train_res, y_train_predict),'\n');
# Out:
# 0.9023696682464455
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.92      0.90      6330
#          1.0       0.91      0.89      0.90      6330
#
#     accuracy                           0.90     12660
#    macro avg       0.90      0.90      0.90     12660
# weighted avg       0.90      0.90      0.90     12660

# %%
#AUC and ROC for the training data
# predict probabilities
probs =GB_SM_Model.predict_proba(X_train_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_train_auc = roc_auc_score(y_train_res, probs)
print('AUC: %.3f' % log_train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.966

# %%
#Test dataset

y_test_predict=GB_SM_Model.predict(X_test)
model_score=GB_SM_Model.score(X_test,y_test)
print(model_score)
plot_confusion_matrix(GB_SM_Model,X_test,y_test)
print(classification_report(y_test, y_test_predict),'\n');
# Out:
# 0.8745306633291614
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92      2702
#          1.0       0.58      0.69      0.63       494
#
#     accuracy                           0.87      3196
#    macro avg       0.76      0.80      0.78      3196
# weighted avg       0.89      0.87      0.88      3196

# %%
# predict probabilities
probs = GB_SM_Model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
log_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % log_test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.897
